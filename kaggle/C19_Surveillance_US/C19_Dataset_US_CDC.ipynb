# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#df = pd.read_csv('./COVID-19_Case_Surveillance_Public_Use_Data.csv', 
                 #keep_default_na=False, nrows=1000000)
df = pd.read_csv('./COVID-19_Case_Surveillance_Public_Use_Data.csv',
                         chunksize=10000)
    
df_no_NaN = pd.DataFrame()
for chunk in df:
    chunk.dropna(inplace=True)
    chunk.info()
    df_no_NaN = df_no_NaN.append(chunk)

#for chunk in pd.read_csv('./COVID-19_Case_Surveillance_Public_Use_Data.csv',
#                         chunksize=10, iterator=True):
#chunk.dropna() # Dropping all rows with any NaN value
#    chunk['sex']
    #df_no_NaN = df_no_NaN.append(chunk)

#df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4538 entries, 1 to 9998
# Data columns (total 11 columns):
# cdc_report_dt                    4538 non-null object
# pos_spec_dt                      4538 non-null object
# onset_dt                         4538 non-null object
# current_status                   4538 non-null object
# sex                              4538 non-null object
# age_group                        4538 non-null object
# Race and ethnicity (combined)    4538 non-null object
# hosp_yn                          4538 non-null object
# icu_yn                           4538 non-null object
# death_yn                         4538 non-null object
# medcond_yn                       4538 non-null object
# dtypes: object(11)
# memory usage: 425.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4251 entries, 10001 to 19997
# Data columns (total 11 columns):
# cdc_report_dt                    4251 non-null object
# ...

# %%
df_no_NaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1386645 entries, 1 to 7494730
# Data columns (total 11 columns):
# cdc_report_dt                    1386645 non-null object
# pos_spec_dt                      1386645 non-null object
# onset_dt                         1386645 non-null object
# current_status                   1386645 non-null object
# sex                              1386645 non-null object
# age_group                        1386645 non-null object
# Race and ethnicity (combined)    1386645 non-null object
# hosp_yn                          1386645 non-null object
# icu_yn                           1386645 non-null object
# death_yn                         1386645 non-null object
# medcond_yn                       1386645 non-null object
# dtypes: object(11)
# memory usage: 127.0+ MB

# %%
df_no_NaN.to_csv('Droped_NA.csv')

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 999999
# Data columns (total 11 columns):
# cdc_report_dt                    1000000 non-null object
# pos_spec_dt                      1000000 non-null object
# onset_dt                         1000000 non-null object
# current_status                   1000000 non-null object
# sex                              1000000 non-null object
# age_group                        1000000 non-null object
# Race and ethnicity (combined)    1000000 non-null object
# hosp_yn                          1000000 non-null object
# icu_yn                           1000000 non-null object
# death_yn                         1000000 non-null object
# medcond_yn                       1000000 non-null object
# dtypes: object(11)
# memory usage: 91.6+ MB

# %%
df.columns
# Out:
# Index(['cdc_report_dt', 'pos_spec_dt', 'onset_dt', 'current_status', 'sex',
#        'age_group', 'Race and ethnicity (combined)', 'hosp_yn', 'icu_yn',
#        'death_yn', 'medcond_yn'],
#       dtype='object')

# %%
df.head()
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic       No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 3  10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 4  10 - 19 Years           Black, Non-Hispanic       No       No       No
#
#   medcond_yn
# 0         No
# 1         No
# 2         No
# 3    Missing
# ...

# %%
df['current_status'].value_counts()
# Out:
# Laboratory-confirmed case    9714
# Probable Case                 286
# Name: current_status, dtype: int64

# %%
df['age_group'].value_counts()
# Out:
# 10 - 19 Years    10000
# Name: age_group, dtype: int64

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4538 entries, 1 to 9998
# Data columns (total 11 columns):
# cdc_report_dt                    4538 non-null object
# pos_spec_dt                      4538 non-null object
# onset_dt                         4538 non-null object
# current_status                   4538 non-null object
# sex                              4538 non-null object
# age_group                        4538 non-null object
# Race and ethnicity (combined)    4538 non-null object
# hosp_yn                          4538 non-null object
# icu_yn                           4538 non-null object
# death_yn                         4538 non-null object
# medcond_yn                       4538 non-null object
# dtypes: object(11)
# memory usage: 425.4+ KB

# %%
df['cdc_report_dt'].value_counts().plot()
