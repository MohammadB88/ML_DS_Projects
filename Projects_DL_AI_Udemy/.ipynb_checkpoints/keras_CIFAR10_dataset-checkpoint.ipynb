# %% [markdown]
# <a id='TOC'></a>
#
# ## TOC:
#
# * [Data Preparation, Analysis, and Visualizations](#Data_Exploration)
# * [Model (CNN without stride) Training](#CNN)
# * [Model Analysis (CNN without stride) (Metrices)](#metrices_CNN)
# * [Model (Strided CNN) Training](#stridedCNN)
# * [Model Analysis (Strided CNN) (Metrices)](#metrices_stridedCNN)
# * [Model (CNN with Pooling) Training Training](#CNN_pool)
# * [Model Analysis (CNN with Pooling) (Metrices)](#metrices_CNN_pool)
# * [Model (add Data Augmentation) Training](#DataAugmentation)
# * [Model Analysis (add Data Augmentation) (Metrices)](#metricesAugmentation)
# * [Model (add Batch Normalization) Training](#BatchNormalization)
# * [Model Analysis (add Batch Normalization) (Metrices)](#metricesBatchNormalization)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# load the required modules to use the Functional API approach
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, Dropout
from tensorflow.keras.layers import MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model

# %% [markdown]
# <a id='Data_Exploration'></a>

# %%
# read in the CIFAR-10 dataset from keras repository
CIFAR10 = tf.keras.datasets.cifar10
(X_train, y_train), (X_test, y_test) = CIFAR10.load_data()

# %%
print(np.shape(X_train), np.shape(y_train), np.shape(y_test), np.shape(X_test))
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 1) (10000, 32, 32, 3)

# %%
plt.imshow(X_train[0])

# %%
plt.imshow(X_test[0])

# %%
# rescale the color range from [0, 255] to [0, 1]
X_train = X_train/255
X_test = X_test/255

# %%
# in order for the model to read the labels, they have to be flatten
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
# read in the number of classes for classification (last layer)
cls = len(set(y_test.flatten()))
print('Number of classes: {}'.format(cls))
# Out:
# Number of classes: 10

# %%
print(np.shape(X_train), np.shape(y_train), np.shape(y_test), np.shape(X_test))
# Out:
# (50000, 32, 32, 3) (50000,) (10000,) (10000, 32, 32, 3)

# %% [markdown]
# <a id='CNN'></a>
# CNN model without stride

# %%
# make the model using the Functional API approach
# In the first LAYER => Input needs the shape of A SINGLE FIGURE
# in this case np.shape(X_train[0]) = (32, 32, 3)
i = Input(shape=np.shape(X_train[0]))
x = Conv2D(32, (3, 3), activation='relu')(i)
x = Conv2D(64, (3, 3), activation='relu')(x)
#x = Conv2D(128, (3, 3), activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(cls, activation='softmax')(x)

# %%
# make the model
model = Model(i, x)

# compile the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# fit the model to the training data
# and validate the model against validation data
# batchsize = number of batches for each SGD step in the training
model.fit(X_train[:10000], y_train[:10000], 
          validation_data=(X_test[:2000], y_test[:2000]), 
          epochs=20, 
          batch_size=128)
# Out:
# Train on 10000 samples, validate on 2000 samples
# Epoch 1/20
# 10000/10000 [==============================] - 59s 6ms/sample - loss: 1.8411 - accuracy: 0.3373 - val_loss: 1.5672 - val_accuracy: 0.4430
# Epoch 2/20
# 10000/10000 [==============================] - 57s 6ms/sample - loss: 1.4068 - accuracy: 0.4970 - val_loss: 1.4987 - val_accuracy: 0.4695
# Epoch 3/20
# 10000/10000 [==============================] - 56s 6ms/sample - loss: 1.2020 - accuracy: 0.5734 - val_loss: 1.3429 - val_accuracy: 0.5115
# Epoch 4/20
# 10000/10000 [==============================] - 59s 6ms/sample - loss: 1.0285 - accuracy: 0.6385 - val_loss: 1.3053 - val_accuracy: 0.5340
# Epoch 5/20
# 10000/10000 [==============================] - 60s 6ms/sample - loss: 0.8300 - accuracy: 0.7074 - val_loss: 1.3329 - val_accuracy: 0.5440
# Epoch 6/20
# 10000/10000 [==============================] - 64s 6ms/sample - loss: 0.6625 - accuracy: 0.7701 - val_loss: 1.3473 - val_accuracy: 0.5520
# Epoch 7/20
# 10000/10000 [==============================] - 67s 7ms/sample - loss: 0.4939 - accuracy: 0.8303 - val_loss: 1.5636 - val_accuracy: 0.5280
# Epoch 8/20
# 10000/10000 [==============================] - 52s 5ms/sample - loss: 0.3755 - accuracy: 0.8728 - val_loss: 1.5140 - val_accuracy: 0.5530
# Epoch 9/20
# 10000/10000 [==============================] - 51s 5ms/sample - loss: 0.2790 - accuracy: 0.9110 - val_loss: 1.6270 - val_accuracy: 0.5525
# Epoch 10/20
# 10000/10000 [==============================] - 59s 6ms/sample - loss: 0.1964 - accuracy: 0.9381 - val_loss: 1.7233 - val_accuracy: 0.5615
# Epoch 11/20
# 10000/10000 [==============================] - 62s 6ms/sample - loss: 0.1665 - accuracy: 0.9462 - val_loss: 1.7790 - val_accuracy: 0.5575
# Epoch 12/20
# 10000/10000 [==============================] - 66s 7ms/sample - loss: 0.1419 - accuracy: 0.9562 - val_loss: 1.9181 - val_accuracy: 0.5560
# Epoch 13/20
# 10000/10000 [==============================] - 51s 5ms/sample - loss: 0.1210 - accuracy: 0.9640 - val_loss: 1.8952 - val_accuracy: 0.5625
# Epoch 14/20
# 10000/10000 [==============================] - 61s 6ms/sample - loss: 0.0940 - accuracy: 0.9729 - val_loss: 1.8974 - val_accuracy: 0.5655
# Epoch 15/20
# 10000/10000 [==============================] - 62s 6ms/sample - loss: 0.0875 - accuracy: 0.9746 - val_loss: 1.9997 - val_accuracy: 0.5635
# Epoch 16/20
# 10000/10000 [==============================] - 71s 7ms/sample - loss: 0.0666 - accuracy: 0.9807 - val_loss: 2.0531 - val_accuracy: 0.5585
# Epoch 17/20
# 10000/10000 [==============================] - 51s 5ms/sample - loss: 0.0613 - accuracy: 0.9819 - val_loss: 2.1196 - val_accuracy: 0.5605
# Epoch 18/20
# 10000/10000 [==============================] - 58s 6ms/sample - loss: 0.0688 - accuracy: 0.9789 - val_loss: 2.1192 - val_accuracy: 0.5685
# Epoch 19/20
# 10000/10000 [==============================] - 50s 5ms/sample - loss: 0.0578 - accuracy: 0.9826 - val_loss: 2.1633 - val_accuracy: 0.5640
# Epoch 20/20
# 10000/10000 [==============================] - 50s 5ms/sample - loss: 0.0481 - accuracy: 0.9861 - val_loss: 2.2351 - val_accuracy: 0.5700

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %% [markdown]
# <a id='metrices_stridedCNN'></a>
# General overview of the  CNN model performance without Strid using Confusion Metrix.

# %%
# 

from sklearn.metrics import confusion_matrix
import itertools

def my_confusion_matrix(con_mat, cls, title='Confusion Matrix', cmap=plt.cm.Blues):
    """
    This Function shows the confusion matrix in a nice format and color.
        
    return:
        It returns nothing and only plot the matrix in a nice format.
    """
    
    #print(con_mat)
    
    plt.figure(figsize=(10,7))
    plt.imshow(con_mat, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    plt.xticks(np.arange(10))
    plt.yticks(np.arange(10))
    
    plt.xlabel('predicted number')
    plt.ylabel('actual number')
    
    #print(range(con_mat.shape[0], con_mat.shape[1]))
    for i, j in itertools.product(range(con_mat.shape[0]), range(con_mat.shape[1])):
        #print(con_mat[i,j])
        plt.text(j, i, con_mat[i,j], 
                 horizontalalignment='center', 
                 color='white' if  i==j else 'black')
    
    plt.tight_layout()
    plt.show()
    
pred = model.predict(X_test)
print(pred[0])

pred_arg = pred.argmax(axis=1)
print(pred_arg[0])

con_mat = confusion_matrix(y_test, pred_arg)
print(con_mat)

my_confusion_matrix(con_mat, list(range(10)))
# Out:
# [1.1470988e-05 5.0806029e-06 5.2623380e-02 8.9744294e-01 3.9232950e-04
#  2.8098742e-02 2.1383783e-02 4.2079871e-05 2.2504342e-07 8.8487155e-09]
# 3
# [[570  38  79  31  36   9  18  24 153  42]
#  [ 21 724  18  18   9   5  19   7  57 122]
#  [ 66  11 466 101  98  70  97  51  28  12]
#  [ 21  22 125 367  84 160 127  55  14  25]
#  [ 29  11 184  66 445  32 106 108  14   5]
#  [ 14   6 114 197  55 431  68  88  18   9]
#  [  4  24  68  77  73  21 683  21  10  19]
#  [ 21  13  51  56  74  77  19 658   6  25]
#  [ 73  88  19  27  16   4  19  10 695  49]
#  [ 23 197  15  35   9   7  28  57  55 574]]

# %% [markdown]
# <a id='stridedCNN'></a>
# CNN model with stride == Strided CNN

# %%
# make the model using the Functional API approach
# In the first LAYER => Input needs the shape of A SINGLE FIGURE
# in this case np.shape(X_train[0]) = (32, 32, 3)
i = Input(shape=np.shape(X_train[0]))
x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(cls, activation='softmax')(x)

# %%
# make the model
model = Model(i, x)

# compile the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# fit the model to the training data
# and validate the model against validation data
# batchsize = number of batches for each SGD step in the training
model.fit(X_train[:10000], y_train[:10000], 
          validation_data=(X_test[:2000], y_test[:2000]), 
          epochs=20, 
          batch_size=128)
# Out:
# Train on 10000 samples, validate on 2000 samples
# Epoch 1/20
# 10000/10000 [==============================] - 4s 447us/sample - loss: 1.9846 - accuracy: 0.2622 - val_loss: 1.7498 - val_accuracy: 0.3765
# Epoch 2/20
# 10000/10000 [==============================] - 4s 396us/sample - loss: 1.6498 - accuracy: 0.3980 - val_loss: 1.6012 - val_accuracy: 0.4165
# Epoch 3/20
# 10000/10000 [==============================] - 4s 402us/sample - loss: 1.5347 - accuracy: 0.4412 - val_loss: 1.4776 - val_accuracy: 0.4530
# Epoch 4/20
# 10000/10000 [==============================] - 4s 353us/sample - loss: 1.4460 - accuracy: 0.4742 - val_loss: 1.3867 - val_accuracy: 0.5030
# Epoch 5/20
# 10000/10000 [==============================] - 4s 412us/sample - loss: 1.3760 - accuracy: 0.4981 - val_loss: 1.4032 - val_accuracy: 0.5105
# Epoch 6/20
# 10000/10000 [==============================] - 4s 368us/sample - loss: 1.3145 - accuracy: 0.5261 - val_loss: 1.3146 - val_accuracy: 0.5280
# Epoch 7/20
# 10000/10000 [==============================] - 4s 391us/sample - loss: 1.2821 - accuracy: 0.5373 - val_loss: 1.3038 - val_accuracy: 0.5310
# Epoch 8/20
# 10000/10000 [==============================] - 4s 405us/sample - loss: 1.2024 - accuracy: 0.5640 - val_loss: 1.3036 - val_accuracy: 0.5330
# Epoch 9/20
# 10000/10000 [==============================] - 4s 411us/sample - loss: 1.1536 - accuracy: 0.5803 - val_loss: 1.2244 - val_accuracy: 0.5620
# Epoch 10/20
# 10000/10000 [==============================] - 5s 520us/sample - loss: 1.1104 - accuracy: 0.6005 - val_loss: 1.2326 - val_accuracy: 0.5720
# Epoch 11/20
# 10000/10000 [==============================] - 10s 993us/sample - loss: 1.0551 - accuracy: 0.6184 - val_loss: 1.2042 - val_accuracy: 0.5700
# Epoch 12/20
# 10000/10000 [==============================] - 10s 953us/sample - loss: 1.0296 - accuracy: 0.6296 - val_loss: 1.2913 - val_accuracy: 0.5615
# Epoch 13/20
# 10000/10000 [==============================] - 10s 1ms/sample - loss: 0.9919 - accuracy: 0.6383 - val_loss: 1.1599 - val_accuracy: 0.5905
# Epoch 14/20
# 10000/10000 [==============================] - 9s 938us/sample - loss: 0.9261 - accuracy: 0.6683 - val_loss: 1.2824 - val_accuracy: 0.5680
# Epoch 15/20
# 10000/10000 [==============================] - 9s 896us/sample - loss: 0.8991 - accuracy: 0.6778 - val_loss: 1.1729 - val_accuracy: 0.5850
# Epoch 16/20
# 10000/10000 [==============================] - 8s 829us/sample - loss: 0.8538 - accuracy: 0.6939 - val_loss: 1.1916 - val_accuracy: 0.5850
# Epoch 17/20
# 10000/10000 [==============================] - 9s 898us/sample - loss: 0.8038 - accuracy: 0.7148 - val_loss: 1.1564 - val_accuracy: 0.6030
# Epoch 18/20
# 10000/10000 [==============================] - 11s 1ms/sample - loss: 0.7799 - accuracy: 0.7226 - val_loss: 1.1894 - val_accuracy: 0.5995
# Epoch 19/20
# 10000/10000 [==============================] - 10s 965us/sample - loss: 0.7541 - accuracy: 0.7303 - val_loss: 1.1562 - val_accuracy: 0.6025
# Epoch 20/20
# 10000/10000 [==============================] - 8s 792us/sample - loss: 0.7043 - accuracy: 0.7435 - val_loss: 1.1440 - val_accuracy: 0.6195

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %% [markdown]
# <a id='metrices_stridedCNN'></a>
# General overview of the performance of the model with Strided CNN using Confusion Metrix.

# %%
# 

from sklearn.metrics import confusion_matrix
import itertools

def my_confusion_matrix(con_mat, cls, title='Confusion Matrix', cmap=plt.cm.Blues):
    """
    This Function shows the confusion matrix in a nice format and color.
        
    return:
        It returns nothing and only plot the matrix in a nice format.
    """
    
    #print(con_mat)
    
    plt.figure(figsize=(10,7))
    plt.imshow(con_mat, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    plt.xticks(np.arange(10))
    plt.yticks(np.arange(10))
    
    plt.xlabel('predicted number')
    plt.ylabel('actual number')
    
    #print(range(con_mat.shape[0], con_mat.shape[1]))
    for i, j in itertools.product(range(con_mat.shape[0]), range(con_mat.shape[1])):
        #print(con_mat[i,j])
        plt.text(j, i, con_mat[i,j], 
                 horizontalalignment='center', 
                 color='white' if  i==j else 'black')
    
    plt.tight_layout()
    plt.show()
    
pred = model.predict(X_test)
print(pred[0])

pred_arg = pred.argmax(axis=1)
print(pred_arg[0])

con_mat = confusion_matrix(y_test, pred_arg)
print(con_mat)

my_confusion_matrix(con_mat, list(range(10)))
# Out:
# [0.00300641 0.01430029 0.06646418 0.33525616 0.00566723 0.47731566
#  0.09012265 0.00288715 0.00435211 0.00062818]
# 5
# [[664  29  55  18  17   8  19  18 124  48]
#  [ 28 719  12  11   4   3  14   4  38 167]
#  [ 69  11 468  73  75  99  95  56  29  25]
#  [ 35  13  98 361  47 219 110  56  21  40]
#  [ 43  13 135  56 435  58 115 117  16  12]
#  [ 21   6  64 161  40 523  69  78  18  20]
#  [ 11  14  44  64  40  24 745  21   9  28]
#  [ 22   9  33  42  58  84  18 685   9  40]
#  [100  66  16  15   6  12  13  13 702  57]
#  [ 48 127   9   9   5  13  25  18  33 713]]

# %% [markdown]
# <a id='CNN_pool'></a>
# CNN model with pooling.

# %%
# make the model using the Functional API approach
# In the first LAYER => Input needs the shape of A SINGLE FIGURE
# in this case np.shape(X_train[0]) = (32, 32, 3)
i = Input(shape=np.shape(X_train[0]))
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(cls, activation='softmax')(x)

# %%
# make the model
model = Model(i, x)

# compile the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# fit the model to the training data
# and validate the model against validation data
# batchsize = number of batches for each SGD step in the training
model.fit(X_train[:10000], y_train[:10000], 
          validation_data=(X_test[:2000], y_test[:2000]), 
          epochs=20, 
          batch_size=128)
# Out:
# Train on 10000 samples, validate on 2000 samples
# Epoch 1/20
# 10000/10000 [==============================] - 16s 2ms/sample - loss: 1.9565 - accuracy: 0.2764 - val_loss: 1.7423 - val_accuracy: 0.3605
# Epoch 2/20
# 10000/10000 [==============================] - 14s 1ms/sample - loss: 1.5772 - accuracy: 0.4241 - val_loss: 1.5364 - val_accuracy: 0.4515
# Epoch 3/20
# 10000/10000 [==============================] - 14s 1ms/sample - loss: 1.4690 - accuracy: 0.4594 - val_loss: 1.3520 - val_accuracy: 0.5230
# Epoch 4/20
# 10000/10000 [==============================] - 14s 1ms/sample - loss: 1.3504 - accuracy: 0.5090 - val_loss: 1.3642 - val_accuracy: 0.5035
# Epoch 5/20
# 10000/10000 [==============================] - 15s 1ms/sample - loss: 1.2603 - accuracy: 0.5417 - val_loss: 1.2309 - val_accuracy: 0.5580
# Epoch 6/20
# 10000/10000 [==============================] - 15s 1ms/sample - loss: 1.1940 - accuracy: 0.5708 - val_loss: 1.2237 - val_accuracy: 0.5575
# Epoch 7/20
# 10000/10000 [==============================] - 14s 1ms/sample - loss: 1.1166 - accuracy: 0.5969 - val_loss: 1.1892 - val_accuracy: 0.5820
# Epoch 8/20
# 10000/10000 [==============================] - 16s 2ms/sample - loss: 1.0574 - accuracy: 0.6187 - val_loss: 1.1252 - val_accuracy: 0.5930
# Epoch 9/20
# 10000/10000 [==============================] - 15s 1ms/sample - loss: 1.0084 - accuracy: 0.6343 - val_loss: 1.1316 - val_accuracy: 0.6050
# Epoch 10/20
# 10000/10000 [==============================] - 15s 1ms/sample - loss: 0.9557 - accuracy: 0.6533 - val_loss: 1.0401 - val_accuracy: 0.6370
# Epoch 11/20
# 10000/10000 [==============================] - 14s 1ms/sample - loss: 0.8870 - accuracy: 0.6794 - val_loss: 1.0580 - val_accuracy: 0.6325
# Epoch 12/20
# 10000/10000 [==============================] - 15s 1ms/sample - loss: 0.8535 - accuracy: 0.6927 - val_loss: 1.0234 - val_accuracy: 0.6375
# Epoch 13/20
# 10000/10000 [==============================] - 16s 2ms/sample - loss: 0.7962 - accuracy: 0.7115 - val_loss: 1.0403 - val_accuracy: 0.6330
# Epoch 14/20
# 10000/10000 [==============================] - 15s 2ms/sample - loss: 0.7610 - accuracy: 0.7287 - val_loss: 1.0107 - val_accuracy: 0.6530
# Epoch 15/20
# 10000/10000 [==============================] - 16s 2ms/sample - loss: 0.7151 - accuracy: 0.7464 - val_loss: 1.0424 - val_accuracy: 0.6485
# Epoch 16/20
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 0.6796 - accuracy: 0.7537 - val_loss: 1.0249 - val_accuracy: 0.6505
# Epoch 17/20
# 10000/10000 [==============================] - 15s 2ms/sample - loss: 0.6247 - accuracy: 0.7806 - val_loss: 1.0424 - val_accuracy: 0.6370
# Epoch 18/20
# 10000/10000 [==============================] - 15s 1ms/sample - loss: 0.6005 - accuracy: 0.7868 - val_loss: 1.0261 - val_accuracy: 0.6750
# Epoch 19/20
# 10000/10000 [==============================] - 15s 2ms/sample - loss: 0.5641 - accuracy: 0.7974 - val_loss: 1.0416 - val_accuracy: 0.6565
# Epoch 20/20
# 10000/10000 [==============================] - 15s 2ms/sample - loss: 0.5185 - accuracy: 0.8188 - val_loss: 1.0203 - val_accuracy: 0.6735

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %% [markdown]
# <a id='metrices_CNN_pool'></a>
# General overview of the performance of the CNN model with pooling using Confusion Metrix.

# %%
# 

from sklearn.metrics import confusion_matrix
import itertools

def my_confusion_matrix(con_mat, cls, title='Confusion Matrix', cmap=plt.cm.Blues):
    """
    This Function shows the confusion matrix in a nice format and color.
        
    return:
        It returns nothing and only plot the matrix in a nice format.
    """
    
    #print(con_mat)
    
    plt.figure(figsize=(10,7))
    plt.imshow(con_mat, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    plt.xticks(np.arange(10))
    plt.yticks(np.arange(10))
    
    plt.xlabel('predicted number')
    plt.ylabel('actual number')
    
    #print(range(con_mat.shape[0], con_mat.shape[1]))
    for i, j in itertools.product(range(con_mat.shape[0]), range(con_mat.shape[1])):
        #print(con_mat[i,j])
        plt.text(j, i, con_mat[i,j], 
                 horizontalalignment='center', 
                 color='white' if  i==j else 'black')
    
    plt.tight_layout()
    plt.show()
    
pred = model.predict(X_test)
print(pred[0])

pred_arg = pred.argmax(axis=1)
print(pred_arg[0])

con_mat = confusion_matrix(y_test, pred_arg)
print(con_mat)

my_confusion_matrix(con_mat, list(range(10)))
# Out:
# [1.4055133e-03 1.3070287e-04 8.2141813e-03 8.7423003e-01 7.4406690e-04
#  9.3878910e-02 4.4671232e-03 4.0737030e-04 1.6453370e-02 6.8628840e-05]
# 3
# [[762  17  28  13  11   4   5  17 114  29]
#  [ 39 775   6   9   2   4   6   9  49 101]
#  [ 99   5 519  52  96  91  46  45  31  16]
#  [ 49   8  89 373  79 241  46  54  33  28]
#  [ 42   3 102  45 577  53  41 111  21   5]
#  [ 28   1  69 108  51 621  26  62  26   8]
#  [ 14   9  56  75  56  43 694  15  23  15]
#  [ 19   1  28  27  55  76   5 759  10  20]
#  [ 59  19   8   6   4   5   1   5 869  24]
#  [ 51  94   5  18   5  12   4  19  52 740]]

# %% [markdown]
# <a id='DataAugmentation'></a>
# Add the Data Augmentation to improve the model.

# %%
# make the model using the Functional API approach
# In the first LAYER => Input needs the shape of A SINGLE FIGURE
# in this case np.shape(X_train[0]) = (32, 32, 3)
i = Input(shape=np.shape(X_train[0]))
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(cls, activation='softmax')(x)

# %%
# make the model
model = Model(i, x)

# compile the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# fit the model to the training data using the Data Augmentation
# and validate the model against validation data
# batchsize = number of batches for each SGD step in the training
batch_size = 128


# create the generator and indicate which features should be changed
batch_size_gen = 128
image_generator = ImageDataGenerator(width_shift_range=0.1, 
                   height_shift_range=0.1, 
                   horizontal_flip=True)

# generate the augmented data
train_generator = image_generator.flow(X_train[:10000], y_train[:10000], 
                                       batch_size=batch_size_gen)

# to make sure 
steps_per_epoch = X_train[:10000].shape[0] // batch_size_gen

model.fit_generator(train_generator, epochs=20, 
                    steps_per_epoch=steps_per_epoch, 
                    validation_data=(X_test[:3000], y_test[:3000])) 
                    #batch_size=batch_size)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 78 steps, validate on 3000 samples
# Epoch 1/20
# 78/78 [==============================] - 24s 312ms/step - loss: 2.1555 - accuracy: 0.3183 - val_loss: 3.7575 - val_accuracy: 0.1507
# Epoch 2/20
# 78/78 [==============================] - 22s 279ms/step - loss: 1.6205 - accuracy: 0.4154 - val_loss: 5.7012 - val_accuracy: 0.2123
# Epoch 3/20
# 78/78 [==============================] - 22s 279ms/step - loss: 1.4902 - accuracy: 0.4572 - val_loss: 5.3290 - val_accuracy: 0.2500
# Epoch 4/20
# 78/78 [==============================] - 22s 279ms/step - loss: 1.4268 - accuracy: 0.4823 - val_loss: 4.2131 - val_accuracy: 0.2893
# Epoch 5/20
# 78/78 [==============================] - 22s 279ms/step - loss: 1.3555 - accuracy: 0.5086 - val_loss: 2.6546 - val_accuracy: 0.3670
# Epoch 6/20
# 78/78 [==============================] - 27s 349ms/step - loss: 1.2970 - accuracy: 0.5320 - val_loss: 1.6795 - val_accuracy: 0.4537
# Epoch 7/20
# 78/78 [==============================] - 23s 293ms/step - loss: 1.2474 - accuracy: 0.5422 - val_loss: 1.5185 - val_accuracy: 0.5377
# Epoch 8/20
# 78/78 [==============================] - 22s 281ms/step - loss: 1.1877 - accuracy: 0.5725 - val_loss: 1.1959 - val_accuracy: 0.5900
# Epoch 9/20
# 78/78 [==============================] - 22s 279ms/step - loss: 1.1429 - accuracy: 0.5904 - val_loss: 1.0639 - val_accuracy: 0.6160
# Epoch 10/20
# 78/78 [==============================] - 22s 279ms/step - loss: 1.0969 - accuracy: 0.6070 - val_loss: 1.0981 - val_accuracy: 0.6093
# Epoch 11/20
# 78/78 [==============================] - 31s 394ms/step - loss: 1.0776 - accuracy: 0.6096 - val_loss: 1.1672 - val_accuracy: 0.6077
# Epoch 12/20
# 78/78 [==============================] - 37s 468ms/step - loss: 1.0496 - accuracy: 0.6247 - val_loss: 1.0547 - val_accuracy: 0.6253
# Epoch 13/20
# 78/78 [==============================] - 36s 462ms/step - loss: 0.9860 - accuracy: 0.6491 - val_loss: 1.1404 - val_accuracy: 0.5990
# Epoch 14/20
# 78/78 [==============================] - 31s 399ms/step - loss: 0.9746 - accuracy: 0.6500 - val_loss: 1.0079 - val_accuracy: 0.6473
# Epoch 15/20
# 78/78 [==============================] - 27s 346ms/step - loss: 0.9237 - accuracy: 0.6668 - val_loss: 1.0644 - val_accuracy: 0.6227
# Epoch 16/20
# 78/78 [==============================] - 40s 507ms/step - loss: 0.9313 - accuracy: 0.6638 - val_loss: 0.9844 - val_accuracy: 0.6590
# Epoch 17/20
# 78/78 [==============================] - 36s 455ms/step - loss: 0.8884 - accuracy: 0.6784 - val_loss: 1.0970 - val_accuracy: 0.6340
# Epoch 18/20
# 78/78 [==============================] - 30s 379ms/step - loss: 0.8731 - accuracy: 0.6891 - val_loss: 1.3526 - val_accuracy: 0.5683
# Epoch 19/20
# 78/78 [==============================] - 22s 282ms/step - loss: 0.8708 - accuracy: 0.6874 - val_loss: 0.9085 - val_accuracy: 0.6843
# Epoch 20/20
# 78/78 [==============================] - 22s 281ms/step - loss: 0.8518 - accuracy: 0.7019 - val_loss: 0.9918 - val_accuracy: 0.6567

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %% [markdown]
# <a id='metricesAugmentation'></a>

# %%
# 

from sklearn.metrics import confusion_matrix
import itertools

def my_confusion_matrix(con_mat, cls, title='Confusion Matrix', cmap=plt.cm.Blues):
    """
    This Function shows the confusion matrix in a nice format and color.
        
    return:
        It returns nothing and only plot the matrix in a nice format.
    """
    
    #print(con_mat)
    
    plt.figure(figsize=(10,7))
    plt.imshow(con_mat, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    plt.xticks(np.arange(10))
    plt.yticks(np.arange(10))
    
    plt.xlabel('predicted number')
    plt.ylabel('actual number')
    
    #print(range(con_mat.shape[0], con_mat.shape[1]))
    for i, j in itertools.product(range(con_mat.shape[0]), range(con_mat.shape[1])):
        #print(con_mat[i,j])
        plt.text(j, i, con_mat[i,j], 
                 horizontalalignment='center', 
                 color='white' if  i==j else 'black')
    
    plt.tight_layout()
    plt.show()
    
pred = model.predict(X_test)
print(pred[0])

pred_arg = pred.argmax(axis=1)
print(pred_arg[0])

con_mat = confusion_matrix(y_test, pred_arg)
print(con_mat)

my_confusion_matrix(con_mat, list(range(10)))
# Out:
# [0.01433445 0.01566324 0.03108765 0.22149429 0.04345499 0.10199396
#  0.09297689 0.04446763 0.23161736 0.20290957]
# 8
# [[705  31  52  10  59   7  15  12  45  64]
#  [ 23 780   1   2   4   0   4   6  14 166]
#  [ 79   9 494  42 132  52  89  49  10  44]
#  [ 16  20  71 349 124 133 118  61  21  87]
#  [ 19   7  64  20 682  16  78  94   8  12]
#  [ 13   5  49 138 123 448  52  88   9  75]
#  [  7  10  27  40  43  16 814  11   7  25]
#  [  8   4  17  16  79  38  14 774   2  48]
#  [ 85  42   8  10  24   1   2   4 731  93]
#  [ 33  52   4   3   6   0   4  12   7 879]]

# %%
# to see the exact labels
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
# read in the list of indices of missclassifed images
missclass_idx = np.where(y_test != pred_arg)[0]
idx_rand = np.random.choice(missclass_idx)
plt.imshow(X_test[idx_rand])
plt.title('Predicted to be "{}", while it actually is "{}"'.format(
    labels[pred_arg[idx_rand]], labels[y_test[idx_rand]]))
# Out:
# Text(0.5, 1.0, 'Predicted to be "bird", while it actually is "airplane"')

# %%
# an overview of the Model
# it makes sence for very large netzworks like CNN 
# with many convolution, pooling and batchnormalization layers
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,148,362
# Trainable params: 1,147,914
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# <a id='BatchNormalization'></a>
# Add the Batch Normalization to improve the model.

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %% [markdown]
# <a id='metricesBatchNormalization'></a>
# Add BatchNormalization to improve the model.

# %%
# make the model using the Functional API approach
# In the first LAYER => Input needs the shape of A SINGLE FIGURE
# in this case np.shape(X_train[0]) = (32, 32, 3)
i = Input(shape=np.shape(X_train[0]))
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(cls, activation='softmax')(x)

# %%
# make the model
model = Model(i, x)

# compile the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# fit the model to the training data
# and validate the model against validation data
# batchsize = number of batches for each SGD step in the training
model.fit(X_train[:10000], y_train[:10000], 
          validation_data=(X_test[:2000], y_test[:2000]), 
          epochs=20, 
          batch_size=128)
# Out:
# Train on 10000 samples, validate on 2000 samples
# Epoch 1/20
# 10000/10000 [==============================] - 24s 2ms/sample - loss: 2.2486 - accuracy: 0.3328 - val_loss: 5.0862 - val_accuracy: 0.1420
# Epoch 2/20
# 10000/10000 [==============================] - 24s 2ms/sample - loss: 1.5246 - accuracy: 0.4455 - val_loss: 5.7917 - val_accuracy: 0.1940
# Epoch 3/20
# 10000/10000 [==============================] - 24s 2ms/sample - loss: 1.3720 - accuracy: 0.5019 - val_loss: 4.8862 - val_accuracy: 0.2615
# Epoch 4/20
# 10000/10000 [==============================] - 24s 2ms/sample - loss: 1.2449 - accuracy: 0.5515 - val_loss: 3.7834 - val_accuracy: 0.2995
# Epoch 5/20
# 10000/10000 [==============================] - 23s 2ms/sample - loss: 1.1492 - accuracy: 0.5836 - val_loss: 2.3251 - val_accuracy: 0.3515
# Epoch 6/20
# 10000/10000 [==============================] - 26s 3ms/sample - loss: 1.0550 - accuracy: 0.6208 - val_loss: 1.7076 - val_accuracy: 0.4710
# Epoch 7/20
# 10000/10000 [==============================] - 25s 2ms/sample - loss: 0.9579 - accuracy: 0.6541 - val_loss: 1.2382 - val_accuracy: 0.5730
# Epoch 8/20
# 10000/10000 [==============================] - 27s 3ms/sample - loss: 0.8953 - accuracy: 0.6785 - val_loss: 1.1071 - val_accuracy: 0.5985
# Epoch 9/20
# 10000/10000 [==============================] - 23s 2ms/sample - loss: 0.8020 - accuracy: 0.7125 - val_loss: 1.0897 - val_accuracy: 0.6195
# Epoch 10/20
# 10000/10000 [==============================] - 29s 3ms/sample - loss: 0.7459 - accuracy: 0.7357 - val_loss: 1.0674 - val_accuracy: 0.6275
# Epoch 11/20
# 10000/10000 [==============================] - 27s 3ms/sample - loss: 0.6906 - accuracy: 0.7517 - val_loss: 1.0579 - val_accuracy: 0.6365
# Epoch 12/20
# 10000/10000 [==============================] - 26s 3ms/sample - loss: 0.6044 - accuracy: 0.7833 - val_loss: 1.0079 - val_accuracy: 0.6590
# Epoch 13/20
# 10000/10000 [==============================] - 25s 3ms/sample - loss: 0.5627 - accuracy: 0.7963 - val_loss: 1.0337 - val_accuracy: 0.6530
# Epoch 14/20
# 10000/10000 [==============================] - 25s 3ms/sample - loss: 0.5110 - accuracy: 0.8168 - val_loss: 1.1046 - val_accuracy: 0.6290
# Epoch 15/20
# 10000/10000 [==============================] - 24s 2ms/sample - loss: 0.4668 - accuracy: 0.8304 - val_loss: 1.0102 - val_accuracy: 0.6605
# Epoch 16/20
# 10000/10000 [==============================] - 27s 3ms/sample - loss: 0.4029 - accuracy: 0.8569 - val_loss: 1.0592 - val_accuracy: 0.6660
# Epoch 17/20
# 10000/10000 [==============================] - 25s 2ms/sample - loss: 0.3843 - accuracy: 0.8620 - val_loss: 1.0669 - val_accuracy: 0.6585
# Epoch 18/20
# 10000/10000 [==============================] - 24s 2ms/sample - loss: 0.3479 - accuracy: 0.8735 - val_loss: 1.1296 - val_accuracy: 0.6595
# Epoch 19/20
# 10000/10000 [==============================] - 25s 2ms/sample - loss: 0.3259 - accuracy: 0.8833 - val_loss: 1.1278 - val_accuracy: 0.6745
# Epoch 20/20
# 10000/10000 [==============================] - 25s 2ms/sample - loss: 0.3125 - accuracy: 0.8905 - val_loss: 1.1231 - val_accuracy: 0.6670

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %% [markdown]
# <a id='metricesBatchNormalization'></a>

# %%
# 

from sklearn.metrics import confusion_matrix
import itertools

def my_confusion_matrix(con_mat, cls, title='Confusion Matrix', cmap=plt.cm.Blues):
    """
    This Function shows the confusion matrix in a nice format and color.
        
    return:
        It returns nothing and only plot the matrix in a nice format.
    """
    
    #print(con_mat)
    
    plt.figure(figsize=(10,7))
    plt.imshow(con_mat, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    plt.xticks(np.arange(10))
    plt.yticks(np.arange(10))
    
    plt.xlabel('predicted number')
    plt.ylabel('actual number')
    
    #print(range(con_mat.shape[0], con_mat.shape[1]))
    for i, j in itertools.product(range(con_mat.shape[0]), range(con_mat.shape[1])):
        #print(con_mat[i,j])
        plt.text(j, i, con_mat[i,j], 
                 horizontalalignment='center', 
                 color='white' if  i==j else 'black')
    
    plt.tight_layout()
    plt.show()
    
pred = model.predict(X_test)
print(pred[0])

pred_arg = pred.argmax(axis=1)
print(pred_arg[0])

con_mat = confusion_matrix(y_test, pred_arg)
print(con_mat)

my_confusion_matrix(con_mat, list(range(10)))
# Out:
# [2.7440174e-03 1.3449245e-04 2.5277629e-01 5.7602054e-01 1.0135476e-05
#  1.0854351e-01 4.3120988e-02 7.9431644e-05 1.6525606e-02 4.4959368e-05]
# 3
# [[748  15  77  17   5   3  19   9  75  32]
#  [ 34 768  14  19   0  11  15   3  59  77]
#  [ 75   3 667  52  41  53  80  13  11   5]
#  [ 27   5 135 472  38 147 138  17  16   5]
#  [ 40   1 173  81 487  33 119  52  14   0]
#  [ 27   2 140 207  30 474  76  32   9   3]
#  [  9   6  62  40  10  11 855   1   6   0]
#  [ 21   2  77  61  79  74  27 649   4   6]
#  [ 78  29  21  19   4   3   8   1 825  12]
#  [ 49  96  16  29   8  13  22  20  55 692]]
