# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# To plot the function in three Dimension
from mpl_toolkits.mplot3d import Axes3D

import tensorflow as tf

# %% [markdown]
# In order to make a synthetic dataset, we implement the function:
#
#     y = cos(2X_1) + cos(3X_2)

# %%
# Make a synthetic dataset
N = 1000 # number of samples

# so that datas are center in the range of [-3, 3]
X = np.random.random((N, 2)) * 6 - 3 
y = np.cos(2 * X[:, 0]) + np.cos(3 * X[:, 1])

# %%
# plot the function
fig = plt.figure(figsize=[7,7])
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], y)

# %%
# create the model and indicate the parameters
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(2))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(1))

# %%
# compile the model
model.compile(optimizer='Adam',
             loss='mse')

# %%
# fit the model to the data
model.fit(X, y, epochs=100)
# Out:
# Train on 1000 samples
# Epoch 1/100
# 1000/1000 [==============================] - 0s 299us/sample - loss: 1.0124
# Epoch 2/100
# 1000/1000 [==============================] - 0s 56us/sample - loss: 0.9711
# Epoch 3/100
# 1000/1000 [==============================] - 0s 57us/sample - loss: 0.9575
# Epoch 4/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.9434
# Epoch 5/100
# 1000/1000 [==============================] - 0s 69us/sample - loss: 0.9411
# Epoch 6/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.9351
# Epoch 7/100
# 1000/1000 [==============================] - 0s 61us/sample - loss: 0.9276
# Epoch 8/100
# 1000/1000 [==============================] - 0s 62us/sample - loss: 0.9242
# Epoch 9/100
# 1000/1000 [==============================] - 0s 58us/sample - loss: 0.9259
# Epoch 10/100
# 1000/1000 [==============================] - 0s 67us/sample - loss: 0.9187
# Epoch 11/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.9143
# Epoch 12/100
# 1000/1000 [==============================] - 0s 66us/sample - loss: 0.9098
# Epoch 13/100
# 1000/1000 [==============================] - 0s 77us/sample - loss: 0.9079
# Epoch 14/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.9039
# Epoch 15/100
# 1000/1000 [==============================] - 0s 55us/sample - loss: 0.9085
# Epoch 16/100
# 1000/1000 [==============================] - 0s 65us/sample - loss: 0.8982
# Epoch 17/100
# 1000/1000 [==============================] - 0s 70us/sample - loss: 0.9029
# Epoch 18/100
# 1000/1000 [==============================] - 0s 60us/sample - loss: 0.9002
# Epoch 19/100
# 1000/1000 [==============================] - 0s 71us/sample - loss: 0.8951
# Epoch 20/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.8952
# Epoch 21/100
# 1000/1000 [==============================] - 0s 77us/sample - loss: 0.8962
# Epoch 22/100
# 1000/1000 [==============================] - 0s 75us/sample - loss: 0.8919
# Epoch 23/100
# 1000/1000 [==============================] - 0s 63us/sample - loss: 0.8934
# Epoch 24/100
# 1000/1000 [==============================] - 0s 58us/sample - loss: 0.8877
# Epoch 25/100
# 1000/1000 [==============================] - 0s 69us/sample - loss: 0.8824
# Epoch 26/100
# 1000/1000 [==============================] - 0s 74us/sample - loss: 0.8855
# Epoch 27/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.8785
# Epoch 28/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.8814
# Epoch 29/100
# 1000/1000 [==============================] - 0s 60us/sample - loss: 0.8786
# Epoch 30/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.8769
# Epoch 31/100
# 1000/1000 [==============================] - 0s 74us/sample - loss: 0.8789
# Epoch 32/100
# 1000/1000 [==============================] - 0s 62us/sample - loss: 0.8822
# Epoch 33/100
# 1000/1000 [==============================] - 0s 65us/sample - loss: 0.8695
# Epoch 34/100
# 1000/1000 [==============================] - 0s 60us/sample - loss: 0.8745
# Epoch 35/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.8676
# Epoch 36/100
# 1000/1000 [==============================] - 0s 66us/sample - loss: 0.8717
# Epoch 37/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8789
# Epoch 38/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.8682
# Epoch 39/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.8619
# Epoch 40/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.8624
# Epoch 41/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.8628
# Epoch 42/100
# 1000/1000 [==============================] - 0s 57us/sample - loss: 0.8545
# Epoch 43/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.8574
# Epoch 44/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8511
# Epoch 45/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.8544
# Epoch 46/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8559
# Epoch 47/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.8592
# Epoch 48/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8474
# Epoch 49/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8462
# Epoch 50/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.8462
# Epoch 51/100
# 1000/1000 [==============================] - 0s 52us/sample - loss: 0.8424
# Epoch 52/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.8392
# Epoch 53/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.8430
# Epoch 54/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.8373
# Epoch 55/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.8350
# Epoch 56/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8325
# Epoch 57/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.8397
# Epoch 58/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8341
# Epoch 59/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.8268
# Epoch 60/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.8236
# Epoch 61/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.8230
# Epoch 62/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.8191
# Epoch 63/100
# 1000/1000 [==============================] - 0s 57us/sample - loss: 0.8183
# Epoch 64/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.8148
# Epoch 65/100
# 1000/1000 [==============================] - 0s 59us/sample - loss: 0.8065
# Epoch 66/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.8068
# Epoch 67/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.8074
# Epoch 68/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.8051
# Epoch 69/100
# 1000/1000 [==============================] - 0s 58us/sample - loss: 0.8067
# Epoch 70/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7974
# Epoch 71/100
# 1000/1000 [==============================] - 0s 50us/sample - loss: 0.7952
# Epoch 72/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.7902
# Epoch 73/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7884
# Epoch 74/100
# 1000/1000 [==============================] - 0s 57us/sample - loss: 0.7907
# Epoch 75/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7829
# Epoch 76/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.7777
# Epoch 77/100
# 1000/1000 [==============================] - 0s 54us/sample - loss: 0.7778
# Epoch 78/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.7715
# Epoch 79/100
# 1000/1000 [==============================] - 0s 50us/sample - loss: 0.7659
# Epoch 80/100
# 1000/1000 [==============================] - 0s 54us/sample - loss: 0.7672
# Epoch 81/100
# 1000/1000 [==============================] - 0s 69us/sample - loss: 0.7684
# Epoch 82/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.7586
# Epoch 83/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.7593
# Epoch 84/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.7538
# Epoch 85/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.7535
# Epoch 86/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7481
# Epoch 87/100
# 1000/1000 [==============================] - 0s 54us/sample - loss: 0.7504
# Epoch 88/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.7486
# Epoch 89/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7439
# Epoch 90/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.7354
# Epoch 91/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.7316
# Epoch 92/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7384
# Epoch 93/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.7437
# Epoch 94/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.7289
# Epoch 95/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.7247
# Epoch 96/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.7344
# Epoch 97/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.7235
# Epoch 98/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7132
# Epoch 99/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.7074
# Epoch 100/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.7078

# %%
# evaluate the model by plotting the loss
plt.plot(model.history.history['loss'], label='loss')
plt.legend()

# %%
print(np.shape(X))
# Out:
# (1000, 2)

# %%
# we plot the predicted (fitted) surface on top of the data
rng = np.linspace(-3, 3, 50)

X_test1, X_test2 = np.meshgrid(rng, rng)
X_test = np.vstack((X_test1.flatten(), X_test2.flatten())).T

y_pred = model.predict(X_test).flatten()

print(np.shape(X_test), np.shape(y_pred))
# Out:
# (2500, 2) (2500,)

# %%
fig = plt.figure(figsize=[7,7])
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], y)
ax.plot_trisurf(X_test[:, 0], X_test[:, 1], y_pred, 
                linewidth=0.2,
               antialiased=True)
plt.show()

# %%
The model perfrormance is not as expected.
Therefore we try to change the hyperparameters:
    
    1. learning rate in adam optimizer
