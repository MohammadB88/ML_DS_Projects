# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import tensorflow as tf

# %%
# read in the MNIST dataset from keras
# It is already separated to Train and Test sets
MNIST = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = MNIST.load_data()

# %%
print(np.shape(X_train), np.shape(X_test))
# Out:
# (60000, 28, 28) (10000, 28, 28)

# %%
print(np.shape(y_train), np.shape(y_test))
# Out:
# (60000,) (10000,)

# %%
plt.imshow(X_train[0], cmap='gray')

# %%
plt.imshow(X_test[0], cmap='gray')

# %%
# create the model and indicate the parameters
model_0 = tf.keras.models.Sequential()
model_0.add(tf.keras.layers.Flatten())
model_0.add(tf.keras.layers.Dense(128, activation='relu'))
model_0.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
# compile the model with corresponding optimization and loss methods
model_0.compile(optimizer='Adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
# fit the model to the train data
model_0.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.1292 - accuracy: 0.9620 - val_loss: 0.1067 - val_accuracy: 0.9675
# Epoch 2/20
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0852 - accuracy: 0.9748 - val_loss: 0.0840 - val_accuracy: 0.9743
# Epoch 3/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.0620 - accuracy: 0.9811 - val_loss: 0.0835 - val_accuracy: 0.9751
# Epoch 4/20
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.0471 - accuracy: 0.9854 - val_loss: 0.0821 - val_accuracy: 0.9741
# Epoch 5/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.0379 - accuracy: 0.9881 - val_loss: 0.0792 - val_accuracy: 0.9767
# Epoch 6/20
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.0301 - accuracy: 0.9904 - val_loss: 0.0683 - val_accuracy: 0.9795
# Epoch 7/20
# ...

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model_0.history.history['loss'], label='loss')
plt.plot(model_0.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model_0.history.history['accuracy'], label='accuracy')
plt.plot(model_0.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %%
# create the model and indicate the parameters
# Add the Dropout layer
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
# compile the model with corresponding optimization and loss methods
model.compile(optimizer='Adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
# fit the model to the train data
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.2990 - accuracy: 0.9132 - val_loss: 0.1394 - val_accuracy: 0.9577
# Epoch 2/20
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.1440 - accuracy: 0.9563 - val_loss: 0.1113 - val_accuracy: 0.9661
# Epoch 3/20
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.1068 - accuracy: 0.9670 - val_loss: 0.0862 - val_accuracy: 0.9739
# Epoch 4/20
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0895 - accuracy: 0.9729 - val_loss: 0.0754 - val_accuracy: 0.9758
# Epoch 5/20
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0746 - accuracy: 0.9764 - val_loss: 0.0747 - val_accuracy: 0.9753
# Epoch 6/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0655 - accuracy: 0.9791 - val_loss: 0.0789 - val_accuracy: 0.9755
# Epoch 7/20
# ...

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %% [markdown]
# The model performance is not as expected.
# Therfore, I think datasets have to be scaled with respect to 255!?

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# create the model and indicate the parameters
model_00 = tf.keras.models.Sequential()
model_00.add(tf.keras.layers.Flatten())
model_00.add(tf.keras.layers.Dense(128, activation='relu'))
model_00.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
# compile the model with corresponding optimization and loss methods
model_00.compile(optimizer='Adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
# fit the model to the train data
model_00.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 6s 101us/sample - loss: 1.1408 - accuracy: 0.7311 - val_loss: 0.5684 - val_accuracy: 0.8522
# Epoch 2/20
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.4706 - accuracy: 0.8756 - val_loss: 0.3881 - val_accuracy: 0.8963
# Epoch 3/20
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.3726 - accuracy: 0.8963 - val_loss: 0.3377 - val_accuracy: 0.9047
# Epoch 4/20
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.3340 - accuracy: 0.9055 - val_loss: 0.3119 - val_accuracy: 0.9093
# Epoch 5/20
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.3114 - accuracy: 0.9113 - val_loss: 0.2935 - val_accuracy: 0.9142
# Epoch 6/20
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.2954 - accuracy: 0.9143 - val_loss: 0.2800 - val_accuracy: 0.9177
# Epoch 7/20
# ...

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model_00.history.history['loss'], label='loss')
plt.plot(model_00.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model_00.history.history['accuracy'], label='accuracy')
plt.plot(model_00.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()

# %%
# create the model and indicate the parameters
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
# compile the model with corresponding optimization and loss methods
model.compile(optimizer='Adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
# fit the model to the train data
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 6s 98us/sample - loss: 1.2229 - accuracy: 0.6817 - val_loss: 0.6115 - val_accuracy: 0.8511
# Epoch 2/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.5367 - accuracy: 0.8548 - val_loss: 0.4144 - val_accuracy: 0.8933
# Epoch 3/20
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.4236 - accuracy: 0.8804 - val_loss: 0.3503 - val_accuracy: 0.9051
# Epoch 4/20
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3749 - accuracy: 0.8924 - val_loss: 0.3207 - val_accuracy: 0.9117
# Epoch 5/20
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3447 - accuracy: 0.9007 - val_loss: 0.2989 - val_accuracy: 0.9140
# Epoch 6/20
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3227 - accuracy: 0.9078 - val_loss: 0.2793 - val_accuracy: 0.9202
# Epoch 7/20
# ...

# %%
# plot the loss and validation loss to observe the model performance
plt.plot(model.history.history['loss'], label='loss')
plt.plot(model.history.history['val_loss'], label='validation loss')
plt.legend()

# %%
# plot the accuracy on Train and Test to observe the model performance
plt.plot(model.history.history['accuracy'], label='accuracy')
plt.plot(model.history.history['val_accuracy'], 
         label='validation accuracy')
plt.legend()
